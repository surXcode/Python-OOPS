# %%
class CarShowroom:
    model = "Scorpio"
    location = "Noida"
    head = "Ashvik"
    esty = 1998

    def __init__(self, model, color,price ,madeyear):
        self.model = model
        self.color = color
        self.price = price
        self.madeyear= madeyear
c= CarShowroom("N","Black",7000000,2020)
print(c.model)
print(c.color)
print(c.price)
print(c.madeyear)
# Out:
# N
# Black
# 7000000
# 2020
