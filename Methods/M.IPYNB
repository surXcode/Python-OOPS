# %% [markdown]
# # Methods: function inside of a class is known as method.
#
# # There are three types of methods:
#
# 1. class method
# 2. object method/instance method
# 3. static method
#
# 1. class method:- It is use to access and modify the class properties.
#
# * classmethod decorator is use before  defining a class method.
#
# * Symbol: #classmethod
#
# * it take the cls first arguments
#
# * cls carries the address of the class or object.
#
# ** Syntax: **
# - class classname:
# - @classmethod
# - def func.name(cls)
# - SB
# - obj = classname()
# - classname func_name()
# - obj.func_name()

# %%
class Bank:
    bname = "BOB"
    loc = "Noida"
    Ifsc = 'BOB123B'
    bmanager = 'Mr.Ashvik'

    @classmethod
    def banks_details(cls):
        print(cls.bname)    
        print(cls.loc)
        print(cls.Ifsc)
        print(cls.bmanager)

    @classmethod
    def change_loc(cls):
        cls.loc = input("Enter the new location :")
        print("Location is change successfully :")
        cls.banks_details()




c1 = Bank()
c2 = Bank()
Bank.change_loc()
# Out:
# Location is change successfully :
# BOB
# u
# BOB123B
# Mr.Ashvik

# %% [markdown]
# 2. object method/instance method:
#
# - It takes mandatory argument the shell.
#
# - self carries the address of object.
#
# - it is use to access and modify.

# %%
class Bank:
    bname = "BOB"
    loc = "Noida"
    Ifsc = 'BOB123B'
    bmanager = 'Mr.Ashvik'

    def __init__(self, name, addr, sal):
        self.name = name
        self.addr = addr
        self.sal = sal

    @classmethod
    def banks_details(cls):
        print(f"Bank name     : {cls.bname}")
        print(f"Location      : {cls.loc}")
        print(f"IFSC code     : {cls.Ifsc}")
        print(f"Bank manager  : {cls.bmanager}")

    def change_address(self):
        self.addr = input("Enter the new address of the customer : ")
        print("Address is changed successfully.")

    def deposit(self):
        pass

    def withdraw(self):
        pass



c1 = Bank('Ashvik', 'Mumbai', 100000)
c2 = Bank('Abhinandan', 'Noida', 200000)


Bank.banks_details()

c1.change_address()
print(c1.addr)

c1.change_address()
print("Updated Address:", c1.addr)
# Out:
# Bank name     : BOB
# Location      : Noida
# IFSC code     : BOB123B
# Bank manager  : Mr.Ashvik
# Address is changed successfully.
# noida
# Address is changed successfully.
# Updated Address: sln

# %%
class Bank:
    bname = "BOB"
    loc = "Noida"
    Ifsc = 'BOB123B'
    bmanager = 'Mr.Ashvik'

    def __init__(self, name, addr, sal):           # constructor method
        self.name = name
        self.addr = addr
        self.sal = sal

    @classmethod
    def banks_details(cls):
        print(f"Bank name     : {cls.bname}")
        print(f"Location      : {cls.loc}")
        print(f"IFSC code     : {cls.Ifsc}")
        print(f"Bank manager  : {cls.bmanager}")

    def change_address(self):
        self.addr = input("Enter the new address of the customer : ")
        print("Address is changed successfully.")



c1 = Bank('Ashvik', 'Mumbai', 100000)
c2 = Bank('Abhinandan', 'Noida', 200000)


Bank.banks_details()

c1.change_address()
print(c1.addr)

c1.change_address()
print("Updated Address:", c1.addr)
# Out:
# Bank name     : BOB
# Location      : Noida
# IFSC code     : BOB123B
# Bank manager  : Mr.Ashvik
# Address is changed successfully.
# sultanpur
# Address is changed successfully.
# Updated Address: kanpur

# %%
class Bank:
    bname = "BOB"
    loc = "Noida"
    ifsc = 'BOB123B'
    bmanager = 'Mr. Ashvik'

    def __init__(self, name, addr, bal):
        self.name = name
        self.addr = addr
        self.bal = bal

    @classmethod
    def bank_details(cls):
        print("Bank Name:", cls.bname)
        print("Location:", cls.loc)
        print("IFSC:", cls.ifsc)
        print("Manager:", cls.bmanager)

    def deposit(self):
        amount = self.get_amount()
        self.bal += amount
        print("Deposited successfully.")
        print(f"Available balance: {self.bal}")

    def withdraw(self):
        amount = self.get_amount()
        if self.bal >= amount:
            self.bal -= amount
            print("Withdrawn successfully.")
            print(f"Available balance: {self.bal}")
        else:
            print("Insufficient balance")

    @staticmethod
    def get_amount():
        return int(input("Enter the amount: "))

    @classmethod
    def change_loc(cls):
        cls.loc = input("Enter the new location: ")
        print("Location changed successfully")
        cls.bank_details()

print("Enter...\\n1 for bank info\n2 for customer info\n3for deposit\n4 for withdraw\n5 for chnage the address\n6 exit")
# Out:
# Enter...\n1 for bank info
# 2 for customer info
# 3for deposit
# 4 for withdraw
# 5 for chnage the address
# 6 exit

# %%
class Bank:
    bname = "BOB"
    loc = "Noida"
    ifsc = 'BOB123B'
    bmanager = 'Mr. Ashvik'

    def __init__(self, name, addr, bal, pin):      # contructor method
        self.name = name
        self.addr = addr
        self.bal = bal
        self.pin = pin

    @classmethod          # decorator class variable ko access krta h
    def bank_details(cls):           # details of bank
        print("Bank Name:", cls.bname)
        print("Location:", cls.loc)
        print("IFSC:", cls.ifsc)
        print("Manager:", cls.bmanager)


    def verify_pin(self):          # instance method
        entered_pin = int(input("Enter your PIN: "))
        return entered_pin == self.pin

    def deposit(self):
        print("---- PIN Verification Required ----")
        if self.verify_pin():
            amount = self.get_amount()
            self.bal += amount
            print("Amount added. Please re-enter PIN to confirm.")


            if self.verify_pin():
                print("Deposited successfully.")
                print(f"Available balance: {self.bal}")
            else:
                print("Wrong PIN. Transaction cancelled.")
                self.bal -= amount
        else:
            print("Wrong PIN. Access denied.")

    def withdraw(self):
        if self.verify_pin():
            amount = self.get_amount()
            if self.bal >= amount:
                self.bal -= amount
                print("Withdrawn successfully.")
                print(f"Available balance: {self.bal}")
            else:
                print("Insufficient balance")
        else:
            print("Wrong PIN. Access denied.")

    @staticmethod
    def get_amount():
        return int(input("Enter the amount: "))

    @classmethod
    def change_loc(cls):
        cls.loc = input("Enter the new location: ")
        print("Location changed successfully")
        cls.bank_details()



c1 = Bank("Ankit", "Noida", 5000,4321)
c2 = Bank("Rahul", "Delhi", 3000, 5678)


c1.deposit()  # object class
c1.withdraw()
# Out:
# ---- PIN Verification Required ----
# Wrong PIN. Access denied.
# Wrong PIN. Access denied.

# %%
class Bank:
    bname = "SBI"
    loc = 'Noida'
    Ifsc = 'SBIN0011'
    bmanager = 'Mr.Nitish'

    def __init__(self,name,addr,bal):
        self.name = name
        self.addr = addr
        self.bal = bal
        

    @classmethod
    def bank_details(cls):
        print(f"Bank name : {cls.bname}")
        print(f"Location : {cls.loc}")
        print(f"IFSC code : {cls.Ifsc}")
        print(f"Bank manager : {cls.bmanager}")

    @classmethod
    def change_location(cls):
        cls.loc =input("Enteer the new address : ")
        print("Location is changed successfully.")
        cls.bank_details()
    
    def customer_details(self):
        print(self.name)
        print(self.addr)
        print(self.bal)

    def change_address(self):
        self.addr = input("Enter the new address of the customer : ")
        print("Addesss is changed successfully.")

    def deposite(self):
        amount = self.get_amount()
        self.bal +=amount
        print("Deposited successfully.")
        print(f"Availbale balance : {self.bal}")


    def withdraw(self):
        amount = self.get_amount()
        if self.bal >=amount:
            self.bal -= amount
            print("Withdrawed successfully.")
            print(f"Availbale balance : {self.bal}")
        else:
            print("Insufficient balance")
        

    @staticmethod
    def get_amount():
        amount = int(input("Enter the amount : "))
        return amount
    

c1 = Bank('Divya','Noida',10000)
c2 = Bank('Nitu','Noida',20000)


while True:
    print("Enter---\n1 for customer details\n2 for change the address\n3 for deposite\n4 for withdraw\n5 for exit")
    choice = int(input("Enter your choice--"))
    
    if choice == 1:
        c1.customer_details()
        print("="*40)
    elif choice == 2:
        c1.change_address()
        print("="*15)
    elif choice == 3:
        c1.deposite()
        print("="*15)
    elif choice == 4:
        c1.withdraw()
        print("="*15)
    elif choice == 5:
        print("Thank you")
        break
    else:
        print("Invalid choice")
        print("="*15)
# Out:
# Enter---
# 1 for customer details
# 2 for change the address
# 3 for deposite
# 4 for withdraw
# 5 for exit
# Addesss is changed successfully.
# ...
# Enter---
# 1 for customer details
# 2 for change the address
# 3 for deposite
# 4 for withdraw
# 5 for exit
# Divya
# niusa
# 10000
# ...
# Enter---
# 1 for customer details
# 2 for change the address
# 3 for deposite
# 4 for withdraw
# 5 for exit
# Divya
# niusa
# 10000
# ...
# Enter---
# 1 for customer details
# 2 for change the address
# 3 for deposite
# 4 for withdraw
# 5 for exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 64
#      62 while True:
#      63     print("Enter---\n1 for customer details\n2 for change the address\n3 for deposite\n4 for withdraw\n5 for exit")
# ---> 64     choice = int(input("Enter your choice--"))
#      66     if choice == 1:
#      67         c1.customer_details()
#
# ...

# %% [markdown]
# # Static Method:
#
# - It is neither related to class nor instance (object).
#
# - It is use to store extra functionality.
#
# - It is used us utility or helper function inside the class.
#
# - it is does 'nt take any mandatory argument like - cls and
#
# - static method decorator is use to define the static method.
#
# # Syntax:
#
# - class class_name:
# -    @staticmethod
# -     def method_name():
# -         SB
#
#
# - class method_name()
# - obj.method_name()

# %%
class Student:
    
    
    def __init__(self, name, roll, marks):
        self.name = name          
        self.roll = roll          
        self.marks = marks        

    
    def display_info(self):
        print("Student Name :", self.name)
        print("Roll Number  :", self.roll)
        print("Marks        :", self.marks)

    
    def grade(self):
        if self.marks >= 90:
            return "A"
        elif self.marks >= 75:
            return "B"
        elif self.marks >= 50:
            return "C"
        else:
            return "D"



s1 = Student("Ashvik", 101, 85)
s2 = Student("Rahul", 102, 45)


s1.display_info()
print("Grade:", s1.grade())

print()

s2.display_info()
print("Grade:", s2.grade())
# Out:
# Student Name : Ashvki
# Roll Number  : 101
# Marks        : 85
# Grade: B
#
# Student Name : Rahul
# Roll Number  : 102
# Marks        : 45
# Grade: D

# %% [markdown]
# # Questions:
#
# 1. How many types of attributes or properties are their?
#
# 2. diff b/w class method and instance method?
#
# 3. How many types of methods there?
#
# 4. diff b/w class property and object property?
#
# 5. what is the use of statice method and how to define it?
